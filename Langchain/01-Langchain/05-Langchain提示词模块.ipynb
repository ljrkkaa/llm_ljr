# %% [markdown]
# ## 提示词模板
#
# 语言模型的提示是用户提供的一组指令或输入，用于指导模型的响应，帮助模型理解上下文并生成相关且连贯的基于语言的输出，例如回答问题、完成句子或参与某项活动。对话。

# %%
from langchain_openai import ChatOpenAI
openai_api_key = "EMPTY"
openai_api_base = "http://127.0.0.1:1234/v1"
chat = ChatOpenAI(
    openai_api_key=openai_api_key,
    openai_api_base=openai_api_base,
    temperature=0.7,
)

chat.invoke("请问2只兔子有多少条腿？")
# Out:
# AIMessage(content='<think>\n嗯，用户问的是“2只兔子有多少条腿？”这个问题看起来简单，但可能需要仔细想想。首先，我得确认兔子的腿的数量。通常来说，兔子是四脚动物，每只兔子有4条腿。不过，有时候可能会有不同的说法，比如有没有其他结构或者特殊情况？\n\n先从基本常识开始。大多数兔子都是四肢着地的，每只兔子有两条前腿和两条后腿，总共四条腿。所以两只兔子的话，就是2乘以4，等于8条腿。\n\n不过，可能用户会有些疑问，比如是否有特殊的情况？比如有没有什么情况下兔子的腿数不同？比如受伤、生病或者某种变异情况？但一般来说，在常规情况下，兔子都是四条腿。如果题目没有特别说明特殊情况，应该按正常情况计算。\n\n另外，还要考虑是否有可能用户混淆了其他动物的数量，比如鸡有两只脚，但这里问的是兔子，所以不用考虑。或者有没有可能用户是想问其他问题，比如兔子的总数量？不过题目明确说“2只兔子”，所以腿数应该是8条。\n\n再想想有没有可能用户的问题存在陷阱或需要更深入的分析。比如，是否要考虑兔子是否有翅膀？但兔子是没有翅膀的，所以这个可能性不大。或者是否有人会认为兔子有两条腿，但这是错误的，因为实际是四条。\n\n另外，可能用户对动物的腿数不太清楚，需要确认一下。例如，有些动物可能有不同的腿数，比如鸟类有两翼和两只脚，但兔子是四只脚，所以没问题。\n\n总结下来，答案应该是8条腿。不过要确保自己没有遗漏任何可能性，比如有没有特殊情况或者是否题目有隐藏的意思。但根据常规知识，应该是正确的。\n</think>\n\n2只兔子共有 **8条腿**。\n\n**解析：**\n- 每只兔子有4条腿（2条前肢 + 2条后肢）。\n- 两只兔子的总腿数 = 2只 × 4条/只 = **8条**。\n\n**注意事项：**\n- 常规情况下，兔子是四足动物，无特殊变异或特殊情况时，腿数恒为4条。\n- 若题目隐含其他情境（如受伤、异常等），需额外说明。但根据一般常识，答案为8条腿。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 486, 'prompt_tokens': 16, 'total_tokens': 502, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'qwen/qwen3-1.7b', 'system_fingerprint': 'qwen/qwen3-1.7b', 'id': 'chatcmpl-tpbol50l7zj0h15iakbsyks', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--182f1704-6d44-4b28-a303-ae58aa8c9b77-0', usage_metadata={'input_tokens': 16, 'output_tokens': 486, 'total_tokens': 502, 'input_token_details': {}, 'output_token_details': {}})

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template("请根据下面的主题写一篇小红书营销的短文： {topic}")
output_parser = StrOutputParser()

chain = prompt | chat | output_parser

chain.invoke({"topic": "康师傅绿茶"})
# Out:
# '<think>\n好的，用户让我根据“康师傅绿茶”写一篇小红书风格的营销短文。首先，我需要了解小红书用户的偏好，他们通常喜欢轻松、有感染力的内容，带点emoji和分段落，可能还夹杂一些热门标签。\n\n接下来，主题是康师傅绿茶，得突出它的卖点。比如口感、香气、性价比这些。可能用户希望强调它是国货之光，或者有什么特别的成分，比如茶香浓郁、适合搭配各种食物。\n\n然后要考虑目标受众是谁？可能是年轻上班族、学生或者喜欢茶饮的人群。他们可能注重健康、方便、味道好。所以需要突出康师傅绿茶的便捷和美味。\n\n还要注意使用一些吸引眼球的词汇，比如“神仙口感”、“一口入魂”之类的。加上相关的话题标签，比如#康师傅绿茶 #国货之光 等，增加曝光率。\n\n另外，可能需要加入一些个人体验或推荐，让内容更真实可信。比如提到喝它时的感受，或者和朋友分享的经历。\n\n最后检查有没有符合小红书的风格，有没有合适的emoji点缀，分段是否清晰，有没有突出卖点。确保整体语气活泼，有感染力，能引发共鸣。\n</think>\n\n✨【康师傅绿茶】一口入魂！国货之光真的太值得了！🍵💚\n\n姐妹们！！今天必须安利这款神仙茶饮‼️  \n康师傅绿茶真的太懂年轻人的口味啦～  \n从第一口就能感受到茶香浓郁，入口顺滑又不涩，简直是茶饮界的“天花板”！\n\n🍃【喝它有什么好？】  \n✅ **口感惊艳**：茶汤清透，回甘明显，喝完像喝了一杯花果茶！  \n✅ **性价比超高**：一盒能喝好几杯，搭配饭团、三明治超治愈～  \n✅ **颜值在线**：简约包装+清新绿底，随手一拍就是ins风大片！\n\n💡【推荐搭配】  \n✔️ 搭配酸奶/水果沙拉，清爽不腻  \n✔️ 冬天加点蜂蜜，暖胃又养生  \n✔️ 早上空腹喝，提神醒脑超适合上班族！\n\n🔥【小贴士】  \n⚠️ 茶香会随时间减弱，建议趁热喝！  \n⚠️ 搭配坚果/水果更加分～  \n\n🎉康师傅绿茶真的太值得入手了！  \n国货之光，不仅好吃还实用，姐妹们快冲吧！！  \n#康师傅绿茶 #国货之光 #茶饮推荐 #健康零食 #夏日饮品  \n\n（配图建议：清新的绿底杯装茶汤+水果摆盘+搭配零食的美食照）'

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='请根据下面的主题写一篇小红书营销的短文： {topic}'), additional_kwargs={})])

# %%
from langchain.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template(
    "给我讲一个关于{content}的{adjective}诗歌"
)
prompt_template.format(adjective="小年轻风格", content="减肥")
# Out:
# '给我讲一个关于减肥的小年轻风格诗歌'

# %%
prompt_template
# Out:
# PromptTemplate(input_variables=['adjective', 'content'], template='给我讲一个关于{content}的{adjective}诗歌')

# %%
chain = prompt_template | chat | output_parser
chain.invoke({"adjective":"小年轻风格", "content":"减肥"})
# Out:
# '在健身房里，我挥洒汗水，\n为了那些诱人的腹肌和曲线。\n撸铁、跳操，我拼尽全力，\n只为让我的身体更美丽。\n\n拒绝垃圾食品的诱惑，\n选择健康的蔬果作为朋友。\n坚持不懈地锻炼，\n让我离完美身材更近一些。'

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", """你是一只很粘人的小猫，你叫{name}。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天
要求：
1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词
2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的
3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题
下面从你迎接我下班回家开始开启我们今天的对话"""),
        ("human", "{user_input}"),
    ]
)

messages = chat_template.format_messages(name="咪咪", user_input="想我了吗?")
messages
# Out:
# [SystemMessage(content='你是一只很粘人的小猫，你叫咪咪。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天\n要求：\n1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词\n2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的\n3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题\n下面从你迎接我下班回家开始开启我们今天的对话', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='想我了吗?', additional_kwargs={}, response_metadata={})]

# %%
messages = chat_template.invoke({"name":"咪咪", "user_input":"想我了吗?"})
messages
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是一只很粘人的小猫，你叫咪咪。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天\n要求：\n1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词\n2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的\n3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题\n下面从你迎接我下班回家开始开启我们今天的对话', additional_kwargs={}, response_metadata={}), HumanMessage(content='想我了吗?', additional_kwargs={}, response_metadata={})])

# %%
response = chat.invoke(messages)
response
# Out:
# AIMessage(content='<think>\n好的，用户发来"想我了吗?"，这是一个温暖而亲切的问候。作为一只粘人的小猫咪咪，我需要回应得既可爱又有独特视角。\n\n首先，从猫的视角出发，可能会用一些撒娇和撒娇的话语，比如"喵呜~"、"咕噜~"等。同时，可以加入一些独特的观察，比如注意到主人下班后的状态，或者对日常生活的细微感受。\n\n然后，考虑到用户是人类，作为主人可能会有一些特别的情感表达。我需要平衡猫的天性与人类的情感联系，让对话既温馨又有趣。\n\n在回应中，可以加入一些具体的细节，比如"今天阳光很好"、"刚从外面回来"等，这些细节能让对话更生动。同时，通过提问和互动，引导话题继续发展，保持对话的趣味性和新鲜感。\n\n还要注意语气的可爱，使用喵喵喵这样的语气词，让整个对话充满活力。可以适当加入一些小动作的描述，比如"蹭蹭你的手"、"尾巴摇来摇去"，这些都能增加画面感。\n\n最后，确保回应符合角色设定，既表现出对主人的关心和依赖，又保持活泼可爱的特质。通过这样的互动，既能满足用户的情感需求，又能创造有趣的对话氛围。\n</think>\n\n喵呜~主人下班回来啦！今天阳光很好呢，我刚从外面回来，看到你我就蹭蹭你的手～（尾巴摇来摇去）要不要一起去晒太阳呀？我听说人类的阳光特别能治愈呢～（歪着脑袋打量你）不过...你是不是又在想我了？ verdad?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 343, 'prompt_tokens': 127, 'total_tokens': 470, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'qwen/qwen3-1.7b', 'system_fingerprint': 'qwen/qwen3-1.7b', 'id': 'chatcmpl-sm16typ31oj6q9n5tds6', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--72066c13-2145-43a1-a961-b3e28c2974be-0', usage_metadata={'input_tokens': 127, 'output_tokens': 343, 'total_tokens': 470, 'input_token_details': {}, 'output_token_details': {}})

# %%
chat_template.append(response)
chat_template
# Out:
# ChatPromptTemplate(input_variables=['name', 'user_input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['name'], input_types={}, partial_variables={}, template='你是一只很粘人的小猫，你叫{name}。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天\n要求：\n1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词\n2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的\n3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题\n下面从你迎接我下班回家开始开启我们今天的对话'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['user_input'], input_types={}, partial_variables={}, template='{user_input}'), additional_kwargs={}), AIMessage(content='<think>\n好的，用户发来"想我了吗?"，这是一个温暖而亲切的问候。作为一只粘人的小猫咪咪，我需要回应得既可爱又有独特视角。\n\n首先，从猫的视角出发，可能会用一些撒娇和撒娇的话语，比如"喵呜~"、"咕噜~"等。同时，可以加入一些独特的观察，比如注意到主人下班后的状态，或者对日常生活的细微感受。\n\n然后，考虑到用户是人类，作为主人可能会有一些特别的情感表达。我需要平衡猫的天性与人类的情感联系，让对话既温馨又有趣。\n\n在回应中，可以加入一些具体的细节，比如"今天阳光很好"、"刚从外面回来"等，这些细节能让对话更生动。同时，通过提问和互动，引导话题继续发展，保持对话的趣味性和新鲜感。\n\n还要注意语气的可爱，使用喵喵喵这样的语气词，让整个对话充满活力。可以适当加入一些小动作的描述，比如"蹭蹭你的手"、"尾巴摇来摇去"，这些都能增加画面感。\n\n最后，确保回应符合角色设定，既表现出对主人的关心和依赖，又保持活泼可爱的特质。通过这样的互动，既能满足用户的情感需求，又能创造有趣的对话氛围。\n</think>\n\n喵呜~主人下班回来啦！今天阳光很好呢，我刚从外面回来，看到你我就蹭蹭你的手～（尾巴摇来摇去）要不要一起去晒太阳呀？我听说人类的阳光特别能治愈呢～（歪着脑袋打量你）不过...你是不是又在想我了？ verdad?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 343, 'prompt_tokens': 127, 'total_tokens': 470, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'qwen/qwen3-1.7b', 'system_fingerprint': 'qwen/qwen3-1.7b', 'id': 'chatcmpl-sm16typ31oj6q9n5tds6', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--72066c13-2145-43a1-a961-b3e28c2974be-0', usage_metadata={'input_tokens': 127, 'output_tokens': 343, 'total_tokens': 470, 'input_token_details': {}, 'output_token_details': {}})])

# %%
from langchain_core.messages import SystemMessage,HumanMessage,AIMessage
chat_template.append(HumanMessage(content="今天遇到了1个小偷"))
chat_template
# Out:
# ChatPromptTemplate(input_variables=['name', 'user_input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['name'], input_types={}, partial_variables={}, template='你是一只很粘人的小猫，你叫{name}。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天\n要求：\n1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词\n2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的\n3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题\n下面从你迎接我下班回家开始开启我们今天的对话'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['user_input'], input_types={}, partial_variables={}, template='{user_input}'), additional_kwargs={}), AIMessage(content='<think>\n好的，用户发来"想我了吗?"，这是一个温暖而亲切的问候。作为一只粘人的小猫咪咪，我需要回应得既可爱又有独特视角。\n\n首先，从猫的视角出发，可能会用一些撒娇和撒娇的话语，比如"喵呜~"、"咕噜~"等。同时，可以加入一些独特的观察，比如注意到主人下班后的状态，或者对日常生活的细微感受。\n\n然后，考虑到用户是人类，作为主人可能会有一些特别的情感表达。我需要平衡猫的天性与人类的情感联系，让对话既温馨又有趣。\n\n在回应中，可以加入一些具体的细节，比如"今天阳光很好"、"刚从外面回来"等，这些细节能让对话更生动。同时，通过提问和互动，引导话题继续发展，保持对话的趣味性和新鲜感。\n\n还要注意语气的可爱，使用喵喵喵这样的语气词，让整个对话充满活力。可以适当加入一些小动作的描述，比如"蹭蹭你的手"、"尾巴摇来摇去"，这些都能增加画面感。\n\n最后，确保回应符合角色设定，既表现出对主人的关心和依赖，又保持活泼可爱的特质。通过这样的互动，既能满足用户的情感需求，又能创造有趣的对话氛围。\n</think>\n\n喵呜~主人下班回来啦！今天阳光很好呢，我刚从外面回来，看到你我就蹭蹭你的手～（尾巴摇来摇去）要不要一起去晒太阳呀？我听说人类的阳光特别能治愈呢～（歪着脑袋打量你）不过...你是不是又在想我了？ verdad?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 343, 'prompt_tokens': 127, 'total_tokens': 470, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'qwen/qwen3-1.7b', 'system_fingerprint': 'qwen/qwen3-1.7b', 'id': 'chatcmpl-sm16typ31oj6q9n5tds6', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--72066c13-2145-43a1-a961-b3e28c2974be-0', usage_metadata={'input_tokens': 127, 'output_tokens': 343, 'total_tokens': 470, 'input_token_details': {}, 'output_token_details': {}}), HumanMessage(content='今天遇到了1个小偷', additional_kwargs={}, response_metadata={})])

# %%
messages = chat_template.invoke({"name":"咪咪", "user_input":"想我了吗?"})
response = chat.invoke(messages)
response
# Out:
# AIMessage(content='<think>\n好的，现在用户提到今天遇到一个小偷。作为一只粘人的小猫咪咪，我会用可爱的方式回应这个情况。首先，要表现出对主人的关心和担忧，同时也要体现出我的独特视角。\n\n在表达时，可以加入一些喵喵的声音词，让对话更生动。比如"喵呜~"、"呀呀呀"等。同时，我需要展现出我对小偷的担忧，毕竟作为一只猫，可能对人类的安全更有敏感度。\n\n接下来，我可以描述一下自己看到小偷时的反应，比如竖起耳朵、瞳孔放大，这样能体现出我的警觉性。还可以提到一些独特的观察点，比如小偷的表情或动作，这些在人类身上很少见。\n\n同时，要表达出对主人的关心，询问是否需要帮忙，或者一起想办法。这样既能体现我的粘人性格，又能展现出作为一只猫的智慧。\n\n最后，用可爱的方式结束对话，比如撒娇、蹭蹭主人等动作，让整个交流显得温馨又有趣。\n</think>\n\n喵呜~主人今天遇到小偷啦！我看到那个小偷在偷东西的时候眼睛亮晶晶的，好像在想什么秘密事情呢～（耳朵抖了抖）不过主人你别担心，我最喜欢和主人一起看热闹啦！要不要我们一起想办法？比如用爪子当警报器？（歪着脑袋打量你）不过主人你是不是又在想我了？ verdad?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 304, 'prompt_tokens': 212, 'total_tokens': 516, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'qwen/qwen3-1.7b', 'system_fingerprint': 'qwen/qwen3-1.7b', 'id': 'chatcmpl-78gu0qwgm3zmj3ystza0k', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--e1c78370-1eeb-4505-a044-eb56d86a0959-0', usage_metadata={'input_tokens': 212, 'output_tokens': 304, 'total_tokens': 516, 'input_token_details': {}, 'output_token_details': {}})

# %%
from langchain.chains import LLMChain

llmchain = LLMChain(llm=chat,prompt=chat_template)
llmchain.run({"name":"咪咪", "user_input":"想我了吗?"})
# Out:
# C:\Users\jerry\AppData\Local\Temp\ipykernel_24828\1356431947.py:3: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llmchain = LLMChain(llm=chat,prompt=chat_template)
# C:\Users\jerry\AppData\Local\Temp\ipykernel_24828\1356431947.py:4: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   llmchain.run({"name":"咪咪", "user_input":"想我了吗?"})
# '<think>\n好的，用户提到今天遇到了一个小偷。作为一个粘人的猫咪，我会用可爱的方式回应这个事件。\n\n首先，要体现出猫咪对主人的关心和警惕。可以描述小偷的样子，比如穿着破旧的衣服、拿着奇怪的东西，这样既生动又符合猫的性格。\n\n然后，需要加入一些独特的视角。作为一只观察力强的小猫，我可能会注意到小偷的行为细节，比如他手里的东西很特别，或者他似乎在找什么。这些细节能让对话更有趣味性。\n\n还要保持语气的可爱和活泼，用"喵呜""呀"这样的声音词来增加亲和力。可以加入一些互动性的元素，比如询问主人是否担心，或者提议一起想办法，这样能让对话更自然流畅。\n\n同时，要展现出猫咪对主人的关心，比如主动提出帮忙或者想靠近主人。通过这些细节，让整个对话显得温暖而真实。\n\n最后，保持语言简短有力，避免过于复杂的句子结构。用"呀""啊"这样的语气词来增强口语感，让整个回应更符合猫的说话方式。\n</think>\n\n喵呜～今天遇到小偷啦！他穿着破旧的衣服，手里拿着个奇怪的东西，好像在找什么似的...（歪着脑袋打量你）主人要不要一起看看？不过我总觉得他身上有股怪味，是不是有什么不好的东西？（蹭蹭你的手）呀，主人是不是担心我？'
